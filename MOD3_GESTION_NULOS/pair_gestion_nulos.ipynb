# %% [markdown]
# # Ejercicios gestión de nulos
#
# -El objetivo del ejercicio es identificar las columnas que contienen valores nulos y aplicar un proceso de imputación para manejarlos de manera adecuada.
#
# -  Puedes utilizar cualquier método o estrategia de imputación que consideres adecuado para los datos y discutir las ventajas y desventajas de tu elección en el informe.

# %% [markdown]
# - Identificación de Valores Nulos: Identifica todas las columnas que contengan valores nulos en el DataFrame.

# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Imputación de nulos usando métodos avanzados estadísticos
# -----------------------------------------------------------------------
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# Librerías de visualización
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt
# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)

# %%
df_w = pd.read_csv("world_data_full_apply.csv", index_col=0)

# %%
df_w["abbreviation"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df_w.isna().sum()/ df_w.shape[0]*100
# Out:
# country                                  0.000000
# density                                  0.000000
# abbreviation                             0.000000
# agricultural_land                        3.589744
# land_area                               15.384615
# armed_forces_size                       14.871795
# birth_rate                               3.076923
# calling_code                             0.512821
# capital/major_city                       1.538462
# co2-emissions                            6.153846
# cpi                                     10.256410
# cpi_change                               8.205128
# currency-code                            7.692308
# fertility_rate                           3.589744
# forested_area                            3.589744
# gasoline_price                          10.256410
# gdp                                      1.025641
# gross_primary_education_enrollment       3.589744
# gross_tertiary_education_enrollment      6.153846
# infant_mortality                         3.076923
# largest_city                             3.076923
# life_expectancy                          4.102564
# maternal_mortality_ratio                 7.179487
# minimum_wage                            23.076923
# official_language                        2.564103
# out_of_pocket_health_expenditure         3.589744
# physicians_per_thousand                  3.589744
# population                              80.000000
# population_labor_force_participation     9.743590
# tax_revenue                             13.333333
# total_tax_rate                           6.153846
# unemployment_rate                        9.743590
# urban_population                        76.923077
# latitude                                 0.512821
# longitude                                0.512821
# continent                                0.512821
# dtype: float64

# %%
df_w["abbreviation"].value_counts(dropna=False)
# Out:
# abbreviation
# NaN    7
# AF     1
# AL     1
# DZ     1
# AD     1
#       ..
# VE     1
# VN     1
# YE     1
# ZM     1
# ZW     1
# Name: count, Length: 189, dtype: int64

# %%
df_w["abbreviation"].value_counts(dropna=False, normalize=True)**100
# Out:
# abbreviation
# NaN    3.208802e-145
# AF     9.920621e-230
# AL     9.920621e-230
# DZ     9.920621e-230
# AD     9.920621e-230
#            ...
# VE     9.920621e-230
# VN     9.920621e-230
# YE     9.920621e-230
# ZM     9.920621e-230
# ZW     9.920621e-230
# Name: proportion, Length: 189, dtype: float64

# %%
df_w["abbreviation"].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: abbreviation, Length: 195, dtype: bool

# %%
df_w[df_w["abbreviation"].isnull()]
# Out:
# Empty DataFrame
# Columns: [country, density, abbreviation, agricultural_land, land_area, armed_forces_size, birth_rate, calling_code, capital/major_city, co2-emissions, cpi, cpi_change, currency-code, fertility_rate, forested_area, gasoline_price, gdp, gross_primary_education_enrollment, gross_tertiary_education_enrollment, infant_mortality, largest_city, life_expectancy, maternal_mortality_ratio, minimum_wage, official_language, out_of_pocket_health_expenditure, physicians_per_thousand, population, population_labor_force_participation, tax_revenue, total_tax_rate, unemployment_rate, urban_population, latitude, longitude, continent]
# Index: []

# %%
df_w["country"]
# Out:
# country
# Afghanistan    0.005128
# Albania        0.005128
# Algeria        0.005128
# Andorra        0.005128
# Angola         0.005128
#                  ...
# Venezuela      0.005128
# Vietnam        0.005128
# Yemen          0.005128
# Zambia         0.005128
# Zimbabwe       0.005128
# Name: proportion, Length: 195, dtype: float64

# %% [markdown]
# - Selección de Método de Imputación: Discute en tu compañera cuál sería la mejor estrategia para manejar los valores nulos en cada una de las columnas identificadas en el paso anterior.

# %%
abreviaciones = {
"Eswatini": "SZ",
"Vatican City": "VA",
"Republic of Ireland": "IE", 
"Republic of the Congo" : "CG",
"Namibia" : "NA",
"North Macedonia": "MK",
"Palestinian National Authority": "PS"
}

for pais,codigo in abreviaciones.items():
    df_w.loc[df_w["country"] == pais, "abbreviation"] = codigo


df_w["abbreviation"].isna().sum()
# Out:
# np.int64(0)

# %%
df_w["abbreviation"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df_w["minimum_wage"]
# Out:
# 0      0.43
# 1      1.12
# 2      0.95
# 3      6.63
# 4      0.71
#        ...
# 190    0.01
# 191    0.73
# 192     NaN
# 193    0.24
# 194     NaN
# Name: minimum_wage, Length: 195, dtype: float64

# %%
df_w["minimum_wage"].value_counts(dropna=False, normalize=True)*100
# Out:
# minimum_wage
# NaN      23.076923
# 2.00      1.538462
# 0.41      1.538462
# 1.12      1.025641
# 0.95      1.025641
#            ...
# 10.13     0.512821
# 7.25      0.512821
# 1.66      0.512821
# 1.56      0.512821
# 0.73      0.512821
# Name: proportion, Length: 115, dtype: float64

# %% [markdown]
# - Imputación de Valores Nulos: Implementa el método de imputación seleccionado en el paso 2 para llenar los valores nulos en las columnas.

# %% [markdown]
# - Informe: Añade al final de un jupyter una explicación breve que describa las columnas que tenían valores nulos, cómo decidiste imputarlos y cualquier observación adicional que consideres importante sobre el proceso de limpieza de datos.
